# %%
for i in range(1,5):
    if(i!=2):
        print(i)
# Out:
# This is a test case

# %%
# ১. একটি লাইব্রেরি ইন্সটল করা (ইন্সটল হচ্ছে কি না দেখার জন্য)
# !pip install cowsay

# ২. লাইব্রেরিটি ইম্পোর্ট করে ব্যবহার করা
import cowsay
import os

# ৩. সিস্টেম ইনফরমেশন প্রিন্ট করা
print("Hello Santanu!")
print(f"Current Environment: {os.environ.get('COLAB_RELEASE_TAG', 'Local Environment')}")

# ৪. একটি মজার আউটপুট দেখা
cowsay.cow('আপনার কোলাব কানেকশন একদম ঠিক আছে!')
# Out:
# ...
# Hello Santanu!
# Current Environment: release-colab-external_20260210-060051_RC00
#   _________________________________
# | আপনার কোলাব কানেকশন একদম ঠিক আছে! |
# ...
#                                  \
#                                   \
#                                     ^__^
#                                     (oo)\_______
#                                     (__)\       )\/\
#                                         ||----w |
#                                         ||     ||

# %%
album_set_1={"AC/DC","Back in Black","Thriller"}
album_set_2={"AC/DC","Back in Black","The Dark Side of the Moon"}
# album_set_3=album_set_1&album_set_2
print(album_set_1.union(album_set_2))
# Out:
# {'The Dark Side of the Moon', 'Back in Black', 'AC/DC', 'Thriller'}
